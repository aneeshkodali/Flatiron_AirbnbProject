# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm




import scrub_and_explore as se
import model as m
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Obtain Data
#
# Airbnb data for Washington DC (as of 9/22/19): http://insideairbnb.com/about.html

# %% [markdown]
# ![image png](img/data.png)
#
# Based on the filters used on Airbnb, we will use the following variables
#
# - guests_included
# - is_business_travel_ready
# - room_type
# - instant_bookable
# - beds
# - bedrooms
# - bathrooms
# - host_is_superhost
# - amenities
# - property_type
# - neighbourhood_cleansed

# %%
listings = pd.read_csv('data/listings.csv.gz')

# Filter dataframe to desired columns
var_list = ['id', 'price', 'guests_included', 'is_business_travel_ready', 'room_type', 'instant_bookable', 'beds', 'bedrooms', 'bathrooms', 'host_is_superhost', 'property_type', 'neighbourhood_cleansed', 'amenities']
listings = listings.loc[:,var_list]

# %% [markdown]
# # Scrub and Explore Data

# %% [markdown]
# ## Clean Data

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9189 entries, 0 to 9188
# Data columns (total 13 columns):
# id                          9189 non-null int64
# price                       9189 non-null object
# guests_included             9189 non-null int64
# is_business_travel_ready    9189 non-null object
# room_type                   9189 non-null object
# instant_bookable            9189 non-null object
# beds                        9180 non-null float64
# bedrooms                    9184 non-null float64
# bathrooms                   9178 non-null float64
# host_is_superhost           9188 non-null object
# property_type               9189 non-null object
# neighbourhood_cleansed      9189 non-null object
# amenities                   9189 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 933.4+ KB

# %% [markdown]
# Couple of things to note:
# - Price is of type object, so we should convert that to numeric
# - There are a few missing values. We will drop them later

# %% [markdown]
# ### Clean price

# %%
listings['price'] = pd.to_numeric(listings['price'].str.replace("$","").str.replace(",",""))

# %% [markdown]
# ### Clean Categorical Variables

# %%
# Create list of categorical variables
categoricalColumns = list(listings.select_dtypes(include=['object']).columns)

for col in categoricalColumns:
    print(f"{col} has {len(listings[col].unique())} values")
    print(listings[col].value_counts()[:5])
    print("\n")
# Out:
# is_business_travel_ready has 1 values
# f    9189
# Name: is_business_travel_ready, dtype: int64
#
#
# room_type has 4 values
# Entire home/apt    6567
# Private room       2363
# Shared room         207
# Hotel room           52
# Name: room_type, dtype: int64
#
#
# instant_bookable has 2 values
# f    4906
# t    4283
# Name: instant_bookable, dtype: int64
#
#
# host_is_superhost has 3 values
# f    6198
# t    2990
# Name: host_is_superhost, dtype: int64
#
#
# property_type has 23 values
# Apartment      4214
# House          1918
# Townhouse      1421
# Condominium     765
# Guest suite     504
# Name: property_type, dtype: int64
#
#
# neighbourhood_cleansed has 39 values
# Columbia Heights, Mt. Pleasant, Pleasant Plains, Park View    911
# Union Station, Stanton Park, Kingman Park                     898
# Capitol Hill, Lincoln Park                                    798
# Edgewood, Bloomingdale, Truxton Circle, Eckington             717
# Dupont Circle, Connecticut Avenue/K Street                    711
# Name: neighbourhood_cleansed, dtype: int64
#
#
# amenities has 8543 values
# {TV,"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Pets allowed",Gym,Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Private entrance","Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"BBQ grill","Patio or balcony","Paid parking on premises"}    45
# {TV,"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,Gym,Elevator,Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware",Oven,Stove}                                                                                                                     36
# {TV,"Cable TV",Wifi,"Air conditioning",Kitchen,Gym,Elevator,Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Pack ’n Play/travel crib","Hot water","Bed linens",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Long term stays allowed"}                                                  25
# {TV,"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Pets allowed",Gym,Elevator,Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace",Bathtub,"Hot water","Bed linens",Refrigerator,Oven,Stove,"Long term stays allowed"}                                                                                                                          19
# {TV,Wifi,"Air conditioning",Kitchen,"Free street parking",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Private living room","Hot water","Bed linens",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Long term stays allowed"}                                    16
# Name: amenities, dtype: int64

# %% [markdown]
# - 'is_business_travel_ready' is 1 value -> drop it since every row has same value
# - 'instant_bookable' is categorical dummy -> convert to dummy
# - 'host_is_superhost' is categorical dummy -> convert to dummy
# - convert 'room_type' to dummy
# - convert 'property_type' to dummy
# - convert 'neighbourhood_cleansed' to dummy
# - convert 'amenities' to dummy

# %%
# Make changes
listings.drop(columns=['is_business_travel_ready'], axis=1, inplace=True)

listings = se.makeDummyColumnFromCategoricalDummyColumn(listings, 'instant_bookable')
listings = se.makeDummyColumnFromCategoricalDummyColumn(listings, 'host_is_superhost')

listings = se.getDummies(listings, 'room_type')
listings = se.getDummies(listings, 'property_type')
listings = se.getDummies(listings, 'neighbourhood_cleansed')

listings = se.makeDummyColumnFromMultivalueColumn(listings, 'amenities', character_list = ["{", "}", "\""], sep=",")

# %% [markdown]
# Just for fun, which neighborhood was dropped when creating dummy variables?

# %%
neighborhoods = list(listings['neighbourhood_cleansed'].unique())
neighborhoods_dummy = [x.replace('neighbourhood_cleansed_EQ_', '') for x in listings.columns if 'neighbourhood_cleansed_EQ_' in x]

set(neighborhoods) - set(neighborhoods_dummy)
# Out:
# {'Brightwood Park, Crestwood, Petworth'}

# %% [markdown]
# Just for fun, which amenity was dropped when creating dummy variables?

# %%
amenities_col = listings['amenities']
character_list = ["{", "}", "\""]
for char in character_list:
    amenities_col = amenities_col.str.replace(char, "")

# Create list of unique values
amenities_list = list(set([x.strip() for l in amenities_col.str.split(",") for x in l]))
amenities_list = [str(x) for x in amenities_list if str(x) not in ['', 'nan']]

amenities_dummy = [x.replace('amenities_EQ_', '') for x in listings.columns if 'amenities_EQ_' in x]

set(amenities_list) - set(amenities_dummy)
# Out:
# {'24-hour check-in'}

# %% [markdown]
# ### Drop Nulls

# %%
listings.dropna(inplace=True)

# %% [markdown]
# ## Explore Data

# %% [markdown]
# Where are listings located?

# %%
se.buildMap(listings, 'price', 'count', 'Number of Listings')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# How expensive are listings?

# %%
se.buildMap(listings, 'price', 'median', 'Median Price of Listings')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Where are the waterfront properties...near water?

# %%
se.buildMap(listings, 'amenities_EQ_Waterfront', 'sum', 'Number of Waterfront Properties')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# How many bedrooms are available?

# %%
se.buildMap(listings, 'bedrooms', 'mean', 'Average Number of Bedrooms')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Model
#
# Can I predict the price of a listing based on its attributes?
#
# I'll use linear regression to do so, in which my dependent (y) variable is my price and my independent (x) variables are the attributes.

# %% [markdown]
# ## Split into Train and Test Data

# %%
y_data = listings[['price']]
# Deleting the original columns that were used to create dummy columns
x_data = listings.drop(columns=['id', 'price', 'room_type', 'instant_bookable', 'host_is_superhost', 'property_type', 'neighbourhood_cleansed', 'amenities'])

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, random_state=20,test_size=0.2)

# %% [markdown]
# ## Standardize Data
#
# I only want to scale the non-dummy columns.

# %%
columnsToScale = ['guests_included', 'beds', 'bedrooms', 'bathrooms']
x_train_scaled, x_test_scaled = m.scaleXData(columnsToScale, x_train, x_test)

# %% [markdown]
# ## Model - Linear Regression

# %%
linReg = m.runSimpleLinearRegression(x_train_scaled, y_train)
labels = ['intercept'] + list(x_train_scaled.columns)
linReg.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     11.50
# Date:                Tue, 25 Feb 2020   Prob (F-statistic):               0.00
# Time:                        08:15:59   Log-Likelihood:                -51444.
# No. Observations:                7336   AIC:                         1.034e+05
# Df Residuals:                    7101   BIC:                         1.050e+05
# Df Model:                         234
# Covariance Type:            nonrobust
# ===============================================================================================================================================================================================
#                                                                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# intercept                                                                                                                     312.9536    166.371      1.881      0.060     -13.183     639.090
# guests_included                                                                                                               -25.2078      4.031     -6.253      0.000     -33.110     -17.306
# beds                                                                                                                           -0.0599      5.393     -0.011      0.991     -10.632      10.513
# bedrooms                                                                                                                       92.7686      5.254     17.657      0.000      82.469     103.068
# bathrooms                                                                                                                      32.4288      4.498      7.209      0.000      23.611      41.246
# instant_bookable_EQ_T                                                                                                          25.8832      6.921      3.740      0.000      12.315      39.451
# host_is_superhost_EQ_T                                                                                                        -24.6027      8.064     -3.051      0.002     -40.411      -8.794
# room_type_EQ_Hotel room                                                                                                       -51.3179     54.642     -0.939      0.348    -158.433      55.797
# room_type_EQ_Private room                                                                                                    -100.2654     10.541     -9.512      0.000    -120.930     -79.601
# room_type_EQ_Shared room                                                                                                     -169.1499     25.336     -6.676      0.000    -218.815    -119.485
# property_type_EQ_Apartment                                                                                                    -79.4985    162.290     -0.490      0.624    -397.635     238.638
# property_type_EQ_Barn                                                                                                        -227.5642    255.534     -0.891      0.373    -728.487     273.358
# property_type_EQ_Bed and breakfast                                                                                            -66.1722    165.783     -0.399      0.690    -391.156     258.812
# property_type_EQ_Boat                                                                                                        -160.4778    260.489     -0.616      0.538    -671.114     350.158
# property_type_EQ_Boutique hotel                                                                                                49.6381    193.370      0.257      0.797    -329.425     428.701
# property_type_EQ_Bungalow                                                                                                     -59.2926    178.542     -0.332      0.740    -409.287     290.702
# property_type_EQ_Condominium                                                                                                  -91.0433    162.659     -0.560      0.576    -409.903     227.817
# property_type_EQ_Cottage                                                                                                     -105.6718    254.309     -0.416      0.678    -604.194     392.850
# property_type_EQ_Dome house                                                                                                  -380.0149    322.264     -1.179      0.238   -1011.747     251.718
# property_type_EQ_Guest suite                                                                                                  -56.1141    163.021     -0.344      0.731    -375.684     263.456
# property_type_EQ_Guesthouse                                                                                                  -105.4069    168.916     -0.624      0.533    -436.532     225.719
# property_type_EQ_Hostel                                                                                                      -116.4075    175.271     -0.664      0.507    -459.990     227.175
# property_type_EQ_Hotel                                                                                                        -92.1321    319.083     -0.289      0.773    -717.630     533.366
# property_type_EQ_House                                                                                                        -27.5781    162.486     -0.170      0.865    -346.099     290.943
# property_type_EQ_Loft                                                                                                         -59.6159    167.209     -0.357      0.721    -387.396     268.165
# property_type_EQ_Other                                                                                                       -103.3683    170.713     -0.606      0.545    -438.016     231.279
# property_type_EQ_Resort                                                                                                        26.7953    319.175      0.084      0.933    -598.883     652.474
# property_type_EQ_Serviced apartment                                                                                           -48.5466    163.385     -0.297      0.766    -368.830     271.737
# property_type_EQ_Tiny house                                                                                                    49.3734    253.357      0.195      0.845    -447.282     546.029
# property_type_EQ_Tipi                                                                                                           4.9346    324.840      0.015      0.988    -631.848     641.718
# property_type_EQ_Townhouse                                                                                                    -68.8109    162.517     -0.423      0.672    -387.394     249.772
# property_type_EQ_Villa                                                                                                       -114.1909    194.035     -0.589      0.556    -494.558     266.176
# neighbourhood_cleansed_EQ_Brookland, Brentwood, Langdon                                                                        17.0984     27.833      0.614      0.539     -37.462      71.659
# neighbourhood_cleansed_EQ_Capitol Hill, Lincoln Park                                                                           98.8115     18.455      5.354      0.000      62.634     134.989
# neighbourhood_cleansed_EQ_Capitol View, Marshall Heights, Benning Heights                                                       4.6640     38.300      0.122      0.903     -70.416      79.744
# neighbourhood_cleansed_EQ_Cathedral Heights, McLean Gardens, Glover Park                                                       69.6777     30.303      2.299      0.022      10.275     129.080
# neighbourhood_cleansed_EQ_Cleveland Park, Woodley Park, Massachusetts Avenue Heights, Woodland-Normanstone Terrace             70.3519     31.725      2.218      0.027       8.162     132.542
# neighbourhood_cleansed_EQ_Colonial Village, Shepherd Park, North Portal Estates                                               -63.1913     51.201     -1.234      0.217    -163.561      37.179
# neighbourhood_cleansed_EQ_Columbia Heights, Mt. Pleasant, Pleasant Plains, Park View                                           24.1758     17.726      1.364      0.173     -10.572      58.923
# neighbourhood_cleansed_EQ_Congress Heights, Bellevue, Washington Highlands                                                      7.3492     37.235      0.197      0.844     -65.642      80.341
# neighbourhood_cleansed_EQ_Deanwood, Burrville, Grant Park, Lincoln Heights, Fairmont Heights                                    0.8249     48.023      0.017      0.986     -93.315      94.964
# neighbourhood_cleansed_EQ_Douglas, Shipley Terrace                                                                             32.3183     59.111      0.547      0.585     -83.556     148.193
# neighbourhood_cleansed_EQ_Downtown, Chinatown, Penn Quarters, Mount Vernon Square, North Capitol Street                       116.6315     23.015      5.068      0.000      71.514     161.749
# neighbourhood_cleansed_EQ_Dupont Circle, Connecticut Avenue/K Street                                                           79.3194     19.468      4.074      0.000      41.156     117.482
# neighbourhood_cleansed_EQ_Eastland Gardens, Kenilworth                                                                        -32.5686    110.733     -0.294      0.769    -249.638     184.501
# neighbourhood_cleansed_EQ_Edgewood, Bloomingdale, Truxton Circle, Eckington                                                    45.0542     18.438      2.444      0.015       8.910      81.198
# neighbourhood_cleansed_EQ_Fairfax Village, Naylor Gardens, Hillcrest, Summit Park                                             -59.5634     58.175     -1.024      0.306    -173.603      54.476
# neighbourhood_cleansed_EQ_Friendship Heights, American University Park, Tenleytown                                            -17.3414     36.078     -0.481      0.631     -88.064      53.381
# neighbourhood_cleansed_EQ_Georgetown, Burleith/Hillandale                                                                     182.2754     24.938      7.309      0.000     133.390     231.161
# neighbourhood_cleansed_EQ_Hawthorne, Barnaby Woods, Chevy Chase                                                                32.5411     41.766      0.779      0.436     -49.333     114.416
# neighbourhood_cleansed_EQ_Historic Anacostia                                                                                  -53.6804     42.328     -1.268      0.205    -136.655      29.295
# neighbourhood_cleansed_EQ_Howard University, Le Droit Park, Cardozo/Shaw                                                       69.2896     22.166      3.126      0.002      25.838     112.741
# neighbourhood_cleansed_EQ_Ivy City, Arboretum, Trinidad, Carver Langston                                                       13.1904     23.488      0.562      0.574     -32.854      59.234
# neighbourhood_cleansed_EQ_Kalorama Heights, Adams Morgan, Lanier Heights                                                       85.8085     21.839      3.929      0.000      42.997     128.620
# neighbourhood_cleansed_EQ_Lamont Riggs, Queens Chapel, Fort Totten, Pleasant Hill                                              31.3103     32.792      0.955      0.340     -32.972      95.592
# neighbourhood_cleansed_EQ_Mayfair, Hillbrook, Mahaning Heights                                                                -52.3843     45.139     -1.161      0.246    -140.871      36.102
# neighbourhood_cleansed_EQ_Near Southeast, Navy Yard                                                                            53.4781     39.410      1.357      0.175     -23.777     130.733
# neighbourhood_cleansed_EQ_North Cleveland Park, Forest Hills, Van Ness                                                         69.4155     42.107      1.649      0.099     -13.127     151.958
# neighbourhood_cleansed_EQ_North Michigan Park, Michigan Park, University Heights                                              -17.6952     36.324     -0.487      0.626     -88.901      53.511
# neighbourhood_cleansed_EQ_River Terrace, Benning, Greenway, Dupont Park                                                        95.4149     46.247      2.063      0.039       4.757     186.073
# neighbourhood_cleansed_EQ_Shaw, Logan Circle                                                                                   94.4161     19.553      4.829      0.000      56.086     132.746
# neighbourhood_cleansed_EQ_Sheridan, Barry Farm, Buena Vista                                                                    14.5221     44.386      0.327      0.744     -72.488     101.532
# neighbourhood_cleansed_EQ_Southwest Employment Area, Southwest/Waterfront, Fort McNair, Buzzard Point                          72.7232     29.543      2.462      0.014      14.810     130.636
# neighbourhood_cleansed_EQ_Spring Valley, Palisades, Wesley Heights, Foxhall Crescent, Foxhall Village, Georgetown Reservoir    13.5150     35.300      0.383      0.702     -55.683      82.714
# neighbourhood_cleansed_EQ_Takoma, Brightwood, Manor Park                                                                      -21.5100     28.111     -0.765      0.444     -76.616      33.596
# neighbourhood_cleansed_EQ_Twining, Fairlawn, Randle Highlands, Penn Branch, Fort Davis Park, Fort Dupont                        8.5042     34.065      0.250      0.803     -58.274      75.282
# neighbourhood_cleansed_EQ_Union Station, Stanton Park, Kingman Park                                                            77.5579     17.809      4.355      0.000      42.647     112.469
# neighbourhood_cleansed_EQ_West End, Foggy Bottom, GWU                                                                         224.2237     25.229      8.888      0.000     174.767     273.680
# neighbourhood_cleansed_EQ_Woodland/Fort Stanton, Garfield Heights, Knox Hill                                                    2.6882     92.837      0.029      0.977    -179.300     184.677
# neighbourhood_cleansed_EQ_Woodridge, Fort Lincoln, Gateway                                                                    -48.8243     40.266     -1.213      0.225    -127.758      30.109
# amenities_EQ_Accessible-height bed                                                                                              1.3015     25.938      0.050      0.960     -49.544      52.147
# amenities_EQ_Accessible-height toilet                                                                                         -20.9836     73.291     -0.286      0.775    -164.656     122.689
# amenities_EQ_Air conditioning                                                                                                 -46.5966     19.762     -2.358      0.018     -85.336      -7.857
# amenities_EQ_Amazon Echo                                                                                                     -212.1062    321.264     -0.660      0.509    -841.879     417.667
# amenities_EQ_BBQ grill                                                                                                         -6.8440     13.633     -0.502      0.616     -33.569      19.881
# amenities_EQ_Baby bath                                                                                                         26.8693     37.283      0.721      0.471     -46.217      99.956
# amenities_EQ_Baby monitor                                                                                                      -4.8516     58.779     -0.083      0.934    -120.076     110.373
# amenities_EQ_Babysitter recommendations                                                                                       -15.4772     23.766     -0.651      0.515     -62.065      31.110
# amenities_EQ_Balcony                                                                                                           74.1346    264.157      0.281      0.779    -443.692     591.961
# amenities_EQ_Bath towel                                                                                                       -31.3637     43.487     -0.721      0.471    -116.610      53.883
# amenities_EQ_Bathroom essentials                                                                                               46.6224     60.319      0.773      0.440     -71.620     164.865
# amenities_EQ_Bathtub                                                                                                          -39.5771     11.614     -3.408      0.001     -62.343     -16.811
# amenities_EQ_Bathtub with bath chair                                                                                            2.3475     99.231      0.024      0.981    -192.176     196.871
# amenities_EQ_Beach essentials                                                                                                  76.2889     70.181      1.087      0.277     -61.288     213.865
# amenities_EQ_Beachfront                                                                                                      -237.4400    221.800     -1.071      0.284    -672.234     197.354
# amenities_EQ_Bed linens                                                                                                       -16.5136     12.412     -1.330      0.183     -40.846       7.818
# amenities_EQ_Bedroom comforts                                                                                                  46.6224     60.319      0.773      0.440     -71.620     164.865
# amenities_EQ_Bidet                                                                                                             93.7616   1174.882      0.080      0.936   -2209.358    2396.881
# amenities_EQ_Body soap                                                                                                        -31.3637     43.487     -0.721      0.471    -116.610      53.883
# amenities_EQ_Breakfast                                                                                                         31.8308     10.900      2.920      0.004      10.463      53.199
# amenities_EQ_Breakfast table                                                                                                   90.5152    210.607      0.430      0.667    -322.337     503.368
# amenities_EQ_Building staff                                                                                                   -83.2167     64.048     -1.299      0.194    -208.770      42.337
# amenities_EQ_Buzzer/wireless intercom                                                                                          -1.8160     17.244     -0.105      0.916     -35.620      31.988
# amenities_EQ_Cable TV                                                                                                          -6.5806      8.173     -0.805      0.421     -22.602       9.441
# amenities_EQ_Carbon monoxide detector                                                                                           9.5802      8.766      1.093      0.274      -7.604      26.765
# amenities_EQ_Cat(s)                                                                                                           -19.2818     27.252     -0.708      0.479     -72.703      34.140
# amenities_EQ_Ceiling fan                                                                                                      211.5065    257.080      0.823      0.411    -292.447     715.460
# amenities_EQ_Central air conditioning                                                                                          74.7056    273.185      0.273      0.785    -460.818     610.229
# amenities_EQ_Changing table                                                                                                     7.5413     45.563      0.166      0.869     -81.777      96.859
# amenities_EQ_Children’s books and toys                                                                                        -31.1616     18.353     -1.698      0.090     -67.139       4.815
# amenities_EQ_Children’s dinnerware                                                                                             16.3394     26.833      0.609      0.543     -36.261      68.940
# amenities_EQ_Cleaning before checkout                                                                                          16.6794     19.985      0.835      0.404     -22.497      55.856
# amenities_EQ_Coffee maker                                                                                                      14.0241     14.080      0.996      0.319     -13.576      41.624
# amenities_EQ_Convection oven                                                                                                   84.9203    333.720      0.254      0.799    -569.270     739.111
# amenities_EQ_Cooking basics                                                                                                   -45.9159     17.676     -2.598      0.009     -80.566     -11.266
# amenities_EQ_Crib                                                                                                             -39.3918     27.919     -1.411      0.158     -94.122      15.339
# amenities_EQ_DVD player                                                                                                      -183.7222    592.897     -0.310      0.757   -1345.977     978.533
# amenities_EQ_Day bed                                                                                                         -106.8887    497.701     -0.215      0.830   -1082.530     868.753
# amenities_EQ_Disabled parking spot                                                                                             -6.3207     42.343     -0.149      0.881     -89.326      76.684
# amenities_EQ_Dishes and silverware                                                                                             20.0902     17.509      1.147      0.251     -14.232      54.412
# amenities_EQ_Dishwasher                                                                                                         2.6986     12.127      0.223      0.824     -21.073      26.470
# amenities_EQ_Dog(s)                                                                                                            -9.3060     24.682     -0.377      0.706     -57.690      39.078
# amenities_EQ_Doorman                                                                                                          -72.3525     22.939     -3.154      0.002    -117.320     -27.385
# amenities_EQ_Double oven                                                                                                     4.029e-13   4.46e-12      0.090      0.928   -8.34e-12    9.15e-12
# amenities_EQ_Dryer                                                                                                             12.9676     28.901      0.449      0.654     -43.687      69.622
# amenities_EQ_EV charger                                                                                                        17.8548     54.983      0.325      0.745     -89.928     125.638
# amenities_EQ_Electric profiling bed                                                                                           -38.4894    175.861     -0.219      0.827    -383.229     306.250
# amenities_EQ_Elevator                                                                                                          19.8738     13.139      1.513      0.130      -5.882      45.630
# amenities_EQ_En suite bathroom                                                                                               -184.6097    359.832     -0.513      0.608    -889.987     520.767
# amenities_EQ_Espresso machine                                                                                                 -20.0128    300.249     -0.067      0.947    -608.590     568.564
# amenities_EQ_Essentials                                                                                                       -12.6523     19.607     -0.645      0.519     -51.087      25.782
# amenities_EQ_Ethernet connection                                                                                              -18.8971     17.075     -1.107      0.268     -52.369      14.575
# amenities_EQ_Exercise equipment                                                                                             -6.719e-12    1.6e-11     -0.420      0.674   -3.81e-11    2.46e-11
# amenities_EQ_Extra pillows and blankets                                                                                         2.3979     12.079      0.199      0.843     -21.280      26.076
# amenities_EQ_Extra space around bed                                                                                            -3.4764     25.865     -0.134      0.893     -54.180      47.227
# amenities_EQ_Family/kid friendly                                                                                               73.9664      7.913      9.348      0.000      58.455      89.478
# amenities_EQ_Fire extinguisher                                                                                                -16.6433      8.299     -2.005      0.045     -32.912      -0.375
# amenities_EQ_Fire pit                                                                                                         -80.1641    814.115     -0.098      0.922   -1676.072    1515.744
# amenities_EQ_Fireplace guards                                                                                                 -30.9420     33.383     -0.927      0.354     -96.384      34.500
# amenities_EQ_Firm mattress                                                                                                     86.0314    106.565      0.807      0.420    -122.867     294.930
# amenities_EQ_First aid kit                                                                                                     -5.5106      7.716     -0.714      0.475     -20.635       9.614
# amenities_EQ_Fixed grab bars for shower                                                                                        54.3419     66.226      0.821      0.412     -75.481     184.165
# amenities_EQ_Fixed grab bars for toilet                                                                                        51.1598    131.635      0.389      0.698    -206.885     309.205
# amenities_EQ_Flat path to guest entrance                                                                                      -13.0719     26.491     -0.493      0.622     -65.002      38.859
# amenities_EQ_Formal dining area                                                                                               134.5177    642.315      0.209      0.834   -1124.611    1393.646
# amenities_EQ_Free parking on premises                                                                                           9.5566      8.230      1.161      0.246      -6.577      25.690
# amenities_EQ_Free street parking                                                                                                1.8211      9.078      0.201      0.841     -15.975      19.617
# amenities_EQ_Full kitchen                                                                                                      -1.2698     35.464     -0.036      0.971     -70.789      68.250
# amenities_EQ_Game console                                                                                                      24.6416     30.845      0.799      0.424     -35.824      85.107
# amenities_EQ_Garden or backyard                                                                                                -2.3173     11.868     -0.195      0.845     -25.581      20.947
# amenities_EQ_Gas oven                                                                                                        -166.2174    393.969     -0.422      0.673    -938.515     606.080
# amenities_EQ_Ground floor access                                                                                             -111.5558    200.578     -0.556      0.578    -504.748     281.637
# amenities_EQ_Gym                                                                                                               75.1907     14.303      5.257      0.000      47.153     103.228
# amenities_EQ_HBO GO                                                                                                          -104.3375    716.282     -0.146      0.884   -1508.465    1299.789
# amenities_EQ_Hair dryer                                                                                                        -8.7757     10.105     -0.868      0.385     -28.584      11.033
# amenities_EQ_Handheld shower head                                                                                              15.2293     31.673      0.481      0.631     -46.859      77.317
# amenities_EQ_Hangers                                                                                                           -6.1712     10.818     -0.570      0.568     -27.377      15.034
# amenities_EQ_Heated floors                                                                                                     61.7949    479.955      0.129      0.898    -879.060    1002.650
# amenities_EQ_Heating                                                                                                          -11.8197     22.558     -0.524      0.600     -56.040      32.400
# amenities_EQ_High chair                                                                                                       -22.4084     21.421     -1.046      0.296     -64.401      19.584
# amenities_EQ_High-resolution computer monitor                                                                                 458.1319    805.490      0.569      0.570   -1120.868    2037.132
# amenities_EQ_Host greets you                                                                                                  -64.8479     15.284     -4.243      0.000     -94.810     -34.886
# amenities_EQ_Hot tub                                                                                                          -15.8135     23.062     -0.686      0.493     -61.021      29.394
# amenities_EQ_Hot water                                                                                                        -20.3393      9.942     -2.046      0.041     -39.828      -0.851
# amenities_EQ_Hot water kettle                                                                                                  28.9714     64.399      0.450      0.653     -97.271     155.213
# amenities_EQ_Indoor fireplace                                                                                                  29.6446     10.284      2.883      0.004       9.485      49.805
# amenities_EQ_Internet                                                                                                         -18.8856      8.522     -2.216      0.027     -35.592      -2.179
# amenities_EQ_Iron                                                                                                             -11.6845     10.441     -1.119      0.263     -32.151       8.782
# amenities_EQ_Jetted tub                                                                                                        28.1808    531.815      0.053      0.958   -1014.334    1070.696
# amenities_EQ_Keypad                                                                                                           -71.0162     58.603     -1.212      0.226    -185.896      43.864
# amenities_EQ_Kitchen                                                                                                          -13.8958     14.208     -0.978      0.328     -41.748      13.956
# amenities_EQ_Kitchenette                                                                                                       26.7142     95.747      0.279      0.780    -160.978     214.406
# amenities_EQ_Lake access                                                                                                      -12.1937     89.709     -0.136      0.892    -188.051     163.663
# amenities_EQ_Laptop friendly workspace                                                                                         15.8751      9.005      1.763      0.078      -1.778      33.528
# amenities_EQ_Lock on bedroom door                                                                                              31.7799      7.438      4.273      0.000      17.200      46.360
# amenities_EQ_Lockbox                                                                                                          -73.8141     58.788     -1.256      0.209    -189.056      41.428
# amenities_EQ_Long term stays allowed                                                                                            3.2326      9.173      0.352      0.725     -14.749      21.215
# amenities_EQ_Luggage dropoff allowed                                                                                            6.8165      9.832      0.693      0.488     -12.456      26.089
# amenities_EQ_Memory foam mattress                                                                                             -52.5760    213.587     -0.246      0.806    -471.269     366.117
# amenities_EQ_Microwave                                                                                                         14.1838     17.829      0.796      0.426     -20.766      49.134
# amenities_EQ_Mini fridge                                                                                                      -17.3959    347.159     -0.050      0.960    -697.931     663.139
# amenities_EQ_Mudroom                                                                                                          610.6533   1515.242      0.403      0.687   -2359.672    3580.979
# amenities_EQ_Murphy bed                                                                                                        65.8672    640.535      0.103      0.918   -1189.773    1321.507
# amenities_EQ_Netflix                                                                                                          147.2652    520.010      0.283      0.777    -872.109    1166.640
# amenities_EQ_No stairs or steps to enter                                                                                       -3.2898     17.923     -0.184      0.854     -38.425      31.845
# amenities_EQ_Other                                                                                                            -90.1310     16.877     -5.340      0.000    -123.215     -57.047
# amenities_EQ_Other pet(s)                                                                                                      38.1837     89.881      0.425      0.671    -138.010     214.378
# amenities_EQ_Outdoor parking                                                                                                 -292.6360    823.568     -0.355      0.722   -1907.074    1321.802
# amenities_EQ_Outdoor seating                                                                                                   50.4725    209.442      0.241      0.810    -360.095     461.040
# amenities_EQ_Outlet covers                                                                                                     15.9109     30.216      0.527      0.599     -43.322      75.144
# amenities_EQ_Oven                                                                                                             -38.6787     18.511     -2.089      0.037     -74.966      -2.391
# amenities_EQ_Pack ’n Play/travel crib                                                                                          35.7134     13.946      2.561      0.010       8.376      63.051
# amenities_EQ_Paid parking off premises                                                                                         -9.5837     12.812     -0.748      0.454     -34.699      15.532
# amenities_EQ_Paid parking on premises                                                                                         -25.4679     15.133     -1.683      0.092     -55.134       4.198
# amenities_EQ_Patio or balcony                                                                                                 -20.5189     10.957     -1.873      0.061     -41.998       0.960
# amenities_EQ_Pets allowed                                                                                                     -24.8825      9.506     -2.617      0.009     -43.518      -6.247
# amenities_EQ_Pets live on this property                                                                                         8.0835     22.257      0.363      0.716     -35.547      51.714
# amenities_EQ_Pillow-top mattress                                                                                              -57.7705    482.503     -0.120      0.905   -1003.620     888.079
# amenities_EQ_Pocket wifi                                                                                                        6.1702     36.080      0.171      0.864     -64.557      76.898
# amenities_EQ_Pool                                                                                                             -56.6933     16.800     -3.375      0.001     -89.626     -23.761
# amenities_EQ_Pool with pool hoist                                                                                               4.3486    102.153      0.043      0.966    -195.902     204.599
# amenities_EQ_Printer                                                                                                         -502.6934   1382.882     -0.364      0.716   -3213.554    2208.167
# amenities_EQ_Private bathroom                                                                                                  87.7239     99.288      0.884      0.377    -106.910     282.358
# amenities_EQ_Private entrance                                                                                                 -36.9509      8.284     -4.461      0.000     -53.190     -20.712
# amenities_EQ_Private living room                                                                                              -16.2043     10.253     -1.580      0.114     -36.303       3.895
# amenities_EQ_Rain shower                                                                                                      178.3417    448.406      0.398      0.691    -700.668    1057.352
# amenities_EQ_Refrigerator                                                                                                       6.5897     20.851      0.316      0.752     -34.285      47.464
# amenities_EQ_Roll-in shower                                                                                                   -10.7813     72.489     -0.149      0.882    -152.882     131.319
# amenities_EQ_Room-darkening shades                                                                                              3.4212     16.860      0.203      0.839     -29.629      36.472
# amenities_EQ_Safety card                                                                                                      -29.9486     10.252     -2.921      0.003     -50.046      -9.851
# amenities_EQ_Self check-in                                                                                                    -10.5818     59.567     -0.178      0.859    -127.352     106.188
# amenities_EQ_Shampoo                                                                                                            8.6193     10.076      0.855      0.392     -11.133      28.371
# amenities_EQ_Shared gym                                                                                                       205.0619   1049.747      0.195      0.845   -1852.754    2262.878
# amenities_EQ_Shower chair                                                                                                     -56.3401     95.010     -0.593      0.553    -242.588     129.907
# amenities_EQ_Single level home                                                                                                 20.5100     18.051      1.136      0.256     -14.876      55.896
# amenities_EQ_Ski-in/Ski-out                                                                                                   -23.5509    222.976     -0.106      0.916    -460.650     413.549
# amenities_EQ_Smart TV                                                                                                        -160.1553    181.355     -0.883      0.377    -515.666     195.355
# amenities_EQ_Smart lock                                                                                                       -55.8292     58.890     -0.948      0.343    -171.271      59.612
# amenities_EQ_Smoke detector                                                                                                   -14.9691     16.843     -0.889      0.374     -47.987      18.048
# amenities_EQ_Smoking allowed                                                                                                   64.6782     22.817      2.835      0.005      19.950     109.407
# amenities_EQ_Soaking tub                                                                                                     -277.6468    823.134     -0.337      0.736   -1891.235    1335.942
# amenities_EQ_Sound system                                                                                                    -365.5370    622.479     -0.587      0.557   -1585.782     854.708
# amenities_EQ_Stair gates                                                                                                      -12.2866     33.756     -0.364      0.716     -78.459      53.885
# amenities_EQ_Standing valet                                                                                                   293.0764    920.566      0.318      0.750   -1511.507    2097.660
# amenities_EQ_Stove                                                                                                             43.6056     20.085      2.171      0.030       4.233      82.978
# amenities_EQ_Suitable for events                                                                                               45.6766     16.112      2.835      0.005      14.092      77.261
# amenities_EQ_TV                                                                                                                45.5623     10.264      4.439      0.000      25.441      65.684
# amenities_EQ_Table corner guards                                                                                               30.8393     72.958      0.423      0.673    -112.180     173.858
# amenities_EQ_Terrace                                                                                                         -161.3316    459.723     -0.351      0.726   -1062.526     739.863
# amenities_EQ_Toilet paper                                                                                                     -31.3637     43.487     -0.721      0.471    -116.610      53.883
# amenities_EQ_Touchless faucets                                                                                               -637.4125    938.558     -0.679      0.497   -2477.266    1202.441
# amenities_EQ_Walk-in shower                                                                                                   -79.2297    220.828     -0.359      0.720    -512.119     353.660
# amenities_EQ_Warming drawer                                                                                                  -318.8952    925.066     -0.345      0.730   -2132.301    1494.510
# amenities_EQ_Washer                                                                                                            -9.4570     29.194     -0.324      0.746     -66.686      47.772
# amenities_EQ_Washer / Dryer                                                                                                   182.7755    159.626      1.145      0.252    -130.138     495.689
# amenities_EQ_Waterfront                                                                                                       175.9937     69.637      2.527      0.012      39.484     312.504
# amenities_EQ_Well-lit path to entrance                                                                                          8.0013     16.211      0.494      0.622     -23.778      39.780
# amenities_EQ_Wheelchair accessible                                                                                              5.9519     22.936      0.259      0.795     -39.010      50.914
# amenities_EQ_Wide clearance to shower                                                                                          -1.3035     52.998     -0.025      0.980    -105.195     102.588
# amenities_EQ_Wide doorway to guest bathroom                                                                                    14.6949     36.494      0.403      0.687     -56.844      86.234
# amenities_EQ_Wide entrance                                                                                                      8.2673     39.190      0.211      0.833     -68.558      85.092
# amenities_EQ_Wide entrance for guests                                                                                          26.6202     39.545      0.673      0.501     -50.900     104.140
# amenities_EQ_Wide entryway                                                                                                      2.1922     30.616      0.072      0.943     -57.825      62.210
# amenities_EQ_Wide hallways                                                                                                     -6.0215     24.954     -0.241      0.809     -54.939      42.896
# amenities_EQ_Wifi                                                                                                               2.7954     22.109      0.126      0.899     -40.544      46.135
# amenities_EQ_Window guards                                                                                                    -24.0418     34.989     -0.687      0.492     -92.631      44.547
# amenities_EQ_Wine cooler                                                                                                      514.5362    670.091      0.768      0.443    -799.042    1828.114
# amenities_EQ_toilet                                                                                                            16.1194     75.932      0.212      0.832    -132.731     164.970
# amenities_EQ_translation missing: en.hosting_amenity_49                                                                        83.9643     15.020      5.590      0.000      54.521     113.408
# amenities_EQ_translation missing: en.hosting_amenity_50                                                                       -26.8601     12.836     -2.093      0.036     -52.022      -1.698
# ==============================================================================
# Omnibus:                    11825.118   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16472468.937
# Skew:                          10.214   Prob(JB):                         0.00
# Kurtosis:                     234.242   Cond. No.                     1.06e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# We have r^2 value of 0.275. Let's see if we can improve on this

# %% [markdown]
# ## Model - Linear Regression Refined
#
# Let's rerun the regression model, this time only using 'significant' variables from the previous regression

# %%
coefTable = m.runSimpleLinearRegression(x_train_scaled, y_train).summary(xname=labels).tables[1]
coefTable = coefTable.data
coefDF = m.makeCoefficientDF(coefTable)


sigVars = coefDF.loc[coefDF['P>|t|']<0.05].index
print(len(sigVars))
x_train_scaled_sigVars = x_train_scaled[sigVars]
x_test_scaled_sigVars = x_test_scaled[sigVars]

linRegRef = m.runSimpleLinearRegression(x_train_scaled_sigVars, y_train)
labels = ['intercept'] + list(x_train_scaled_sigVars.columns)

linRegRef.summary(xname=labels)
# Out:
# 48
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     51.13
# Date:                Tue, 25 Feb 2020   Prob (F-statistic):               0.00
# Time:                        08:15:59   Log-Likelihood:                -51558.
# No. Observations:                7336   AIC:                         1.032e+05
# Df Residuals:                    7287   BIC:                         1.036e+05
# Df Model:                          48
# Covariance Type:            nonrobust
# ======================================================================================================================================================================================
#                                                                                                                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# intercept                                                                                                            228.7750     20.404     11.212      0.000     188.776     268.774
# guests_included                                                                                                      -27.2195      3.886     -7.005      0.000     -34.837     -19.603
# bedrooms                                                                                                              94.3789      4.422     21.345      0.000      85.711     103.046
# bathrooms                                                                                                             34.1685      3.907      8.744      0.000      26.509      41.828
# instant_bookable_EQ_T                                                                                                 23.9892      6.712      3.574      0.000      10.832      37.146
# host_is_superhost_EQ_T                                                                                               -28.7879      7.579     -3.798      0.000     -43.645     -13.931
# room_type_EQ_Private room                                                                                            -86.5838      9.013     -9.606      0.000    -104.252     -68.915
# room_type_EQ_Shared room                                                                                            -163.8197     23.425     -6.993      0.000    -209.739    -117.901
# neighbourhood_cleansed_EQ_Capitol Hill, Lincoln Park                                                                  82.9804     12.454      6.663      0.000      58.568     107.393
# neighbourhood_cleansed_EQ_Cathedral Heights, McLean Gardens, Glover Park                                              61.2138     27.013      2.266      0.023       8.261     114.166
# neighbourhood_cleansed_EQ_Cleveland Park, Woodley Park, Massachusetts Avenue Heights, Woodland-Normanstone Terrace    55.1170     28.546      1.931      0.054      -0.841     111.075
# neighbourhood_cleansed_EQ_Downtown, Chinatown, Penn Quarters, Mount Vernon Square, North Capitol Street               97.4343     17.675      5.513      0.000      62.787     132.082
# neighbourhood_cleansed_EQ_Dupont Circle, Connecticut Avenue/K Street                                                  58.0803     13.222      4.393      0.000      32.161      83.999
# neighbourhood_cleansed_EQ_Edgewood, Bloomingdale, Truxton Circle, Eckington                                           28.7723     12.724      2.261      0.024       3.830      53.715
# neighbourhood_cleansed_EQ_Georgetown, Burleith/Hillandale                                                            162.1363     20.250      8.007      0.000     122.440     201.833
# neighbourhood_cleansed_EQ_Howard University, Le Droit Park, Cardozo/Shaw                                              48.1216     17.299      2.782      0.005      14.210      82.033
# neighbourhood_cleansed_EQ_Kalorama Heights, Adams Morgan, Lanier Heights                                              69.6914     16.506      4.222      0.000      37.335     102.048
# neighbourhood_cleansed_EQ_River Terrace, Benning, Greenway, Dupont Park                                               87.6332     43.830      1.999      0.046       1.714     173.552
# neighbourhood_cleansed_EQ_Shaw, Logan Circle                                                                          74.3065     13.546      5.485      0.000      47.752     100.861
# neighbourhood_cleansed_EQ_Southwest Employment Area, Southwest/Waterfront, Fort McNair, Buzzard Point                 57.4856     25.415      2.262      0.024       7.664     107.307
# neighbourhood_cleansed_EQ_Union Station, Stanton Park, Kingman Park                                                   65.0459     11.758      5.532      0.000      41.998      88.094
# neighbourhood_cleansed_EQ_West End, Foggy Bottom, GWU                                                                214.6543     20.038     10.713      0.000     175.375     253.934
# amenities_EQ_Air conditioning                                                                                        -55.9675     18.422     -3.038      0.002     -92.079     -19.856
# amenities_EQ_Bathtub                                                                                                 -45.7531     10.353     -4.419      0.000     -66.047     -25.459
# amenities_EQ_Breakfast                                                                                                31.1292     10.376      3.000      0.003      10.790      51.468
# amenities_EQ_Cooking basics                                                                                          -27.7265     15.371     -1.804      0.071     -57.859       2.406
# amenities_EQ_Doorman                                                                                                 -69.6041     21.549     -3.230      0.001    -111.847     -27.361
# amenities_EQ_Family/kid friendly                                                                                      72.2006      7.656      9.431      0.000      57.193      87.209
# amenities_EQ_Fire extinguisher                                                                                       -23.9063      7.575     -3.156      0.002     -38.755      -9.058
# amenities_EQ_Gym                                                                                                      86.9050     12.319      7.054      0.000      62.756     111.054
# amenities_EQ_Host greets you                                                                                         -18.6145     13.619     -1.367      0.172     -45.311       8.082
# amenities_EQ_Hot water                                                                                               -58.0076      8.201     -7.073      0.000     -74.084     -41.931
# amenities_EQ_Indoor fireplace                                                                                         28.7518      9.765      2.945      0.003       9.610      47.893
# amenities_EQ_Internet                                                                                                -18.1680      7.757     -2.342      0.019     -33.375      -2.961
# amenities_EQ_Lock on bedroom door                                                                                     26.0097      7.143      3.642      0.000      12.008      40.011
# amenities_EQ_Other                                                                                                   -34.6075     15.014     -2.305      0.021     -64.039      -5.176
# amenities_EQ_Oven                                                                                                    -50.2428     15.995     -3.141      0.002     -81.598     -18.888
# amenities_EQ_Pack ’n Play/travel crib                                                                                 12.8267     11.801      1.087      0.277     -10.306      35.959
# amenities_EQ_Pets allowed                                                                                            -26.0627      9.169     -2.842      0.004     -44.037      -8.088
# amenities_EQ_Pool                                                                                                    -53.0363     16.020     -3.311      0.001     -84.440     -21.633
# amenities_EQ_Private entrance                                                                                        -43.3220      7.755     -5.586      0.000     -58.524     -28.120
# amenities_EQ_Safety card                                                                                             -33.1389      9.673     -3.426      0.001     -52.100     -14.178
# amenities_EQ_Smoking allowed                                                                                          74.1890     22.372      3.316      0.001      30.334     118.044
# amenities_EQ_Stove                                                                                                    57.8272     18.709      3.091      0.002      21.152      94.503
# amenities_EQ_Suitable for events                                                                                      34.5594     15.531      2.225      0.026       4.114      65.005
# amenities_EQ_TV                                                                                                       37.8888      9.424      4.020      0.000      19.415      56.363
# amenities_EQ_Waterfront                                                                                              127.4113     62.392      2.042      0.041       5.105     249.717
# amenities_EQ_translation missing: en.hosting_amenity_49                                                               82.4067     14.818      5.561      0.000      53.359     111.454
# amenities_EQ_translation missing: en.hosting_amenity_50                                                              -26.1958     12.710     -2.061      0.039     -51.111      -1.280
# ==============================================================================
# Omnibus:                    11765.583   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15549973.548
# Skew:                          10.126   Prob(JB):                         0.00
# Kurtosis:                     227.638   Cond. No.                         45.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# We now have R^2 of 0.252. Considering that there were hundreds of variables in the original model, filtering down the variable set to only a fraction of that with only a 0.02 difference in R^2 is quite an improvement.

# %% [markdown]
# ## Model - Ridge Regression

# %%
alpha_array = np.array([1000, 100, 10, 1, .1, .01, .001, 0])

# From our alpha array, determine best alpha to use for ridge regression

grid_search_ridge = m.conductGridSearch(model=Ridge(), alpha_array=alpha_array, x_data=x_train_scaled, y_data=y_train)
best_alpha_ridge = grid_search_ridge.best_estimator_.alpha
# Out:
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
# Ridge Regression
ridge = m.runRidgeRegression(x_train_scaled, y_train, best_alpha_ridge)
print(f"Ridge R^2: {ridge.score(x_train_scaled, y_train)}")
print(f"Ridge # features: {len([x for x in ridge.coef_[0] if abs(x)>10**-2])}")
# Out:
# Ridge R^2: 0.26430057963731823
# Ridge # features: 237

# %% [markdown]
# ## Model - Lasso Regression

# %%
# From our alpha array, determine best alpha to use for lasso regression

grid_search_lasso = m.conductGridSearch(model=Lasso(), alpha_array=alpha_array, x_data=x_train_scaled, y_data=y_train)
best_alpha_lasso = grid_search_lasso.best_estimator_.alpha
# Out:
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88974160.83493254, tolerance: 38656.84341188139
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4781802.993364394, tolerance: 54646.172972398286
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88741987.3135631, tolerance: 52768.671661255365
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133638274.96764292, tolerance: 38656.84341188139
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197639819.76023215, tolerance: 54646.172972398286
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\anees\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190197952.1966163, tolerance: 52768.671661255365
#   positive)

# %%
# Lasso Regression
lasso = m.runLassoRegression(x_train_scaled, y_train, best_alpha_lasso)
print(f"Lasso R^2: {lasso.score(x_train_scaled, y_train)}")
print(f"Lasso # features: {len([x for x in lasso.coef_ if abs(x)>10**-2])}")
# Out:
# Lasso R^2: 0.2532599313192625
# Lasso # features: 60

# %% [markdown]
# The tests produced similar R^2. The refined Linear Regression has fewest variables, so I will use that.

# %% [markdown]
# # Interpret

# %% [markdown]
# Let's look at the variable table and see which variables have the highest effect on price

# %%
# Create another column for absolute value of coef
coefDF['coefABS'] = coefDF['coef'].apply(lambda x: abs(x))

# %%
# Top 10 variables
coefDF.sort_values(by='coefABS', ascending=False).head()
# Out:
# 0                                                  coef   std err      t  \
#
# amenities_EQ_Touchless faucets                -637.4125   938.558 -0.679
# amenities_EQ_Mudroom                           610.6533  1515.242  0.403
# amenities_EQ_Wine cooler                       514.5362   670.091  0.768
# amenities_EQ_Printer                          -502.6934  1382.882 -0.364
# amenities_EQ_High-resolution computer monitor  458.1319   805.490  0.569
#
# 0                                              P>|t|    [0.025    0.975]  \
#
# amenities_EQ_Touchless faucets                 0.497 -2477.266  1202.441
# amenities_EQ_Mudroom                           0.687 -2359.672  3580.979
# amenities_EQ_Wine cooler                       0.443  -799.042  1828.114
# amenities_EQ_Printer                           0.716 -3213.554  2208.167
# amenities_EQ_High-resolution computer monitor  0.570 -1120.868  2037.132
#
# 0                                               coefABS
#
# amenities_EQ_Touchless faucets                 637.4125
# amenities_EQ_Mudroom                           610.6533
# amenities_EQ_Wine cooler                       514.5362
# amenities_EQ_Printer                           502.6934
# amenities_EQ_High-resolution computer monitor  458.1319

# %%
# Bottom 10 variables
coefDF.sort_values(by='coefABS', ascending=False).tail()
# Out:
# 0                                                           coef  \
#
# amenities_EQ_Full kitchen                          -1.269800e+00
# neighbourhood_cleansed_EQ_Deanwood, Burrville, ...  8.249000e-01
# beds                                               -5.990000e-02
# amenities_EQ_Exercise equipment                    -6.719000e-12
# amenities_EQ_Double oven                            4.029000e-13
#
# 0                                                        std err      t  \
#
# amenities_EQ_Full kitchen                           3.546400e+01 -0.036
# neighbourhood_cleansed_EQ_Deanwood, Burrville, ...  4.802300e+01  0.017
# beds                                                5.393000e+00 -0.011
# amenities_EQ_Exercise equipment                     1.600000e-11 -0.420
# amenities_EQ_Double oven                            4.460000e-12  0.090
#
# 0                                                   P>|t|        [0.025  \
#
# amenities_EQ_Full kitchen                           0.971 -7.078900e+01
# neighbourhood_cleansed_EQ_Deanwood, Burrville, ...  0.986 -9.331500e+01
# beds                                                0.991 -1.063200e+01
# amenities_EQ_Exercise equipment                     0.674 -3.810000e-11
# amenities_EQ_Double oven                            0.928 -8.340000e-12
#
# 0                                                         0.975]       coefABS
#
# amenities_EQ_Full kitchen                           6.825000e+01  1.269800e+00
# neighbourhood_cleansed_EQ_Deanwood, Burrville, ...  9.496400e+01  8.249000e-01
# beds                                                1.051300e+01  5.990000e-02
# amenities_EQ_Exercise equipment                     2.460000e-11  6.719000e-12
# amenities_EQ_Double oven                            9.150000e-12  4.029000e-13

# %%
# Rerun Linear Regression using sci-kit learn
lm = LinearRegression()
lm.fit(x_train_scaled_sigVars, y_train)
y_train_pred = lm.predict(x_train_scaled_sigVars)
r2_score(y_train, y_train_pred)
# Out:
# 0.251927331132777

# %%
# Applying model to test data
y_test_pred = lm.predict(x_test_scaled_sigVars)
r2_score(y_test, y_test_pred)
# Out:
# 0.2808436392800463

# %% [markdown]
# Our test dataset produced a r^2 value of 0.28, an increase from our training r^2 score. A couple of things to note:
# - the data doesn't factor in occupancy rate. So an owner can put a listing on the site, but it's unclear if that listing has been reserved at that price
# - since amenities are self-reported, reporting certain amenities are voluntary. So if a listing lacks a certain amenitity, it MIGHT be the case that the owner didn't feel the need to list an amenitiy
# - there's the possibility that more amenities could relate to a decrease in price. The owner may not feel confident about the listing and may try to compensate by listing a lot more amenities than usual, and it may be unclear if listings have listed amenities based on the data alone.
#
# These reasons could explain while r^2 has been consistently low.
